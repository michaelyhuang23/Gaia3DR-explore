# %%
import sys
sys.path.append('..')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn import metrics
from cluster_analysis import C_HDBSCAN, C_GaussianMixture
from evaluation_metrics import ClusterEvalIoU, ClusterEvalMode
from recurse_cluster import RecursiveCluster
from pingouin import multivariate_normality

# %%
df = pd.read_hdf('../data/m12f_cluster_data_large_mass_large_cluster_v2.h5', key='star')
df['cluster_id_name'] = np.array([f'cluster {id}' for id in df['cluster_id'].to_numpy()])
#chosen_cluster_ids = np.random.choice(np.arange(1,27), 26, replace=False)
#chosen_ids = np.argwhere(df['cluster_id'].isin(chosen_cluster_ids).to_numpy())[:,0]
chosen_ids = np.random.choice(len(df), min(len(df), 10000))
df = df.iloc[chosen_ids].copy()
df = df.reset_index()
df.head()
# Out:
#     index  Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1       feH  id_stars  \
# 0  458002        458002      458002        458002 -1.556742  14809296
# 1  306488        306488      306488        306488 -0.934090   5110531
# 2  322468        322468      322468        322468 -1.005718   8245005
# 3  403142        403142      403142        403142 -1.143487  13663988
# 4  331011        331011      331011        331011 -1.420494   9581553
#
#    radial_distance_stars  redshift_stars  snap_list_stars    star_mass  ...  \
# 0               3.786520        5.000000               67  4703.701411  ...
# 1              11.587580        0.799427              312  5073.704293  ...
# 2               9.720855        0.799427              312  5154.492395  ...
# 3               3.600455        3.000000              120  5268.952530  ...
# 4              14.350273        0.799427              312  4898.112381  ...
#
#            pstar         kstar       lxstar       lystar       lzstar  \
# 0 -234438.060133  31725.135281  -680.397001    65.331875   420.347327
# 1 -160236.387665  63809.005863    59.757199 -1334.040507   187.349856
# 2 -177346.109292  62313.446311  -450.139500 -1445.246644   954.719934
# 3 -240307.324497  19185.855836   171.552015  -263.031583  -152.287878
# 4 -157316.017926  54222.464553 -1505.508100   755.427726  2518.528823
#
#      apostar  peristar   eccstar   zmaxstar  cluster_id_name
# 0   4.977036  2.197419  0.387433   4.187208       cluster 15
# 1  37.624447  4.566144  0.783547  33.207100       cluster 22
# 2  26.628347  2.744199  0.813145  18.068226       cluster 22
# 3   4.629294  0.611681  0.766577   3.563884        cluster 3
# 4  32.912159  5.914997  0.695316  11.140133       cluster 22
#
# [5 rows x 53 columns]

# %%
np.unique(df['redshift_stars'])
# Out:
# array([0.30020699, 0.3986637 , 0.59796441, 0.70189703, 0.79942691,
#        0.89728099, 1.        , 1.5       , 2.        , 2.5056181 ,
#        3.        , 4.        , 5.        , 6.        ])

# %%
df = df.loc[(df['redshift_stars']==1.5) | (df['redshift_stars']==2)]

# %%
df['redshift_stars_names'] = np.array([f'reshift {redshift}' if redshift<3 else 'old' for redshift in df['redshift_stars'].to_numpy()])

# %%
df['lstar'] = np.linalg.norm([df['lzstar'].to_numpy(),df['lystar'].to_numpy(),df['lxstar'].to_numpy()],axis=0)
df['c_lzstar'] = df['lzstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lystar'] = df['lystar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lxstar'] = df['lxstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
l # mostly spherical because you can try squaring it
df['a_jzrstar'] = df['jzstar'].to_numpy() + df['jrstar'].to_numpy() # mostly spherical because you can try squaring it
df['rstar'] = np.linalg.norm([df['xstar'].to_numpy(),df['ystar'].to_numpy(),df['zstar'].to_numpy()],axis=0)

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.scatterplot(data=df, ax=axes[0,0], x='lzstar', y='estar', hue='redshift_stars')
sns.scatterplot(data=df, ax=axes[0,1], x='lystar', y='estar', hue='redshift_stars')
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue='redshift_stars')
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='jzstar', hue='redshift_stars')
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='jrstar', hue='redshift_stars')
sns.scatterplot(data=df, ax=axes[1,2], x='feH', y='mgfe', hue='redshift_stars')
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
cluster1 = C_HDBSCAN(metric='manhattan', min_cluster_size=10, min_samples=4, cluster_selection_method='leaf', cluster_selection_epsilon=0.01)
cluster1.config()
# action diamond

# %%
selected_columns=['estar', 'c_lzstar', 'c_lxstar', 'c_lystar', 's_jzrstar', 'a_jzrstar', 'jphistar', 'eccstar', 'rstar', 'feH', 'mgfe', 'zmaxstar']
simple_selected_columns=['estar', 'lzstar', 'lxstar', 'lystar', 'jzstar', 'jrstar', 'jphistar', 'eccstar', 'rstar', 'feH', 'mgfe', 'zmaxstar']

# %%
cluster1.add_data(df, columns=simple_selected_columns)
labels = cluster1.fit()

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy(), IoU_thres=0.5)
print(eval_IoU1())
print(eval_IoU1.TP)
print(eval_IoU1.T)
print(eval_IoU1.P)
purity_score(df['cluster_id'].to_numpy(), labels)
# IoU metric makes no sense when the cutoff is below 0.5
# Out:
# (0.0, 0.0)
# 0
# 26
# 25
# 0.4085

# %%
eval_Mode = ClusterEvalMode(labels, df['cluster_id'].to_numpy())
print(eval_Mode())
print(eval_Mode.TP)
print(eval_Mode.T)
print(eval_Mode.P)
# Out:
# (0.0, 0.0)
# 0
# 26
# 25

# %%
AMI = sklearn.metrics.adjusted_mutual_info_score(df['cluster_id'].to_numpy(), labels)
RAND = sklearn.metrics.adjusted_rand_score(df['cluster_id'].to_numpy(), labels)
print(AMI, RAND)
# Out:
# 0.05002523509365197 0.005969873516923408

# %%
df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0', 'Unnamed: 0.1'])
df.index.is_unique
# Out:
# True

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.kdeplot(data=df, ax=axes[0,0], x='c_lzstar', y='estar')
sns.kdeplot(data=df, ax=axes[0,1], x='c_lystar', y='estar')
sns.kdeplot(data=df, ax=axes[0,2], x='rstar', y='eccstar')
sns.kdeplot(data=df, ax=axes[1,0], x='jphistar', y='s_jzrstar')
sns.kdeplot(data=df, ax=axes[1,1], x='jphistar', y='a_jzrstar')
sns.kdeplot(data=df, ax=axes[1,2], x='feH', y='mgfe')
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>
# Error in callback <function flush_figures at 0x128460ca0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
# -> 2299         bbox_inches = self.figure.get_tightbbox(
#    2300             renderer, bbox_extra_artists=bbox_extra_artists)
#    2301         if pad_inches is None:
#    2302             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/figure.py:1693, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1689 if ax.get_visible():
#    1690     # some axes don't take the bbox_extra_artists kwarg so we
#    1691     # need this conditional....
#    1692     try:
# -> 1693         bbox = ax.get_tightbbox(
#    1694             renderer, bbox_extra_artists=bbox_extra_artists)
#    1695     except TypeError:
#    1696         bbox = ax.get_tightbbox(renderer)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axes/_base.py:4628, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4626 if self.xaxis.get_visible():
#    4627     try:
# -> 4628         bb_xaxis = self.xaxis.get_tightbbox(
#    4629             renderer, for_layout_only=for_layout_only)
#    4630     except TypeError:
#    4631         # in case downstream library has redefined axis:
#    4632         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axis.py:1105, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1101     return
#    1103 ticks_to_draw = self._update_ticks()
# -> 1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#    1108 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1109             ticks_to_draw, renderer)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axis.py:2083, in XAxis._update_label_position(self, renderer)
#    2079     return
#    2081 # get bounding boxes for this axis and any siblings
#    2082 # that have been set by `fig.align_xlabels()`
# -> 2083 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2085 x, y = self.label.get_position()
#    2086 if self.label_position == 'bottom':
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axis.py:1881, in Axis._get_tick_boxes_siblings(self, renderer)
#    1879 axis = getattr(ax, f"{axis_name}axis")
#    1880 ticks_to_draw = axis._update_ticks()
# -> 1881 tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882 bboxes.extend(tlb)
#    1883 bboxes2.extend(tlb2)
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axis.py:1085, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/axis.py:1085, in <listcomp>(.0)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/text.py:910, in Text.get_window_extent(self, renderer, dpi)
#     907     raise RuntimeError('Cannot get window extent w/o renderer')
#     909 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910     bbox, info, descent = self._get_layout(self._renderer)
#     911     x, y = self.get_unitless_position()
#     912     x, y = self.get_transform().transform((x, y))
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/text.py:309, in Text._get_layout(self, renderer)
#     306 ys = []
#     308 # Full vertical extent of font, including ascenders and descenders:
# --> 309 _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     310     "lp", self._fontproperties,
#     311     ismath="TeX" if self.get_usetex() else False)
#     312 min_dy = (lp_h - lp_d) * self._linespacing
#     314 for i, line in enumerate(lines):
#
# File ~/ProjectData/virtual-env/gaia/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:270, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     268 flags = get_hinting_flag()
#     269 font = self._get_agg_font(prop)
# --> 270 font.set_text(s, 0.0, flags=flags)
#     271 w, h = font.get_width_height()  # width and height of unrotated string
#     272 d = font.get_descent()
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
label_names = np.array([f'cluster {id}' for id in labels])
sns.scatterplot(data=df, ax=axes[0,0], x='c_lzstar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,1], x='c_lystar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='s_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='a_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,2], x='feH', y='mgfe', hue=label_names)
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
cluster2 = C_GaussianMixture(n_components=26)

# %%
cluster2.add_data(df, columns=simple_selected_columns)
labels2 = cluster2.fit(epoch = 100)

# %%
eval_IoU2 = ClusterEvalIoU(labels2, df['cluster_id'].to_numpy(), IoU_thres=0.3)
print(eval_IoU2())
print(eval_IoU2.TP)
print(eval_IoU2.T)
print(eval_IoU2.P)
# Out:
# (0.0, 0.0)
# 0
# 26
# 26

# %%
eval_Mode2 = ClusterEvalMode(labels2, df['cluster_id'].to_numpy())
print(eval_Mode2())
print(eval_Mode2.TP)
print(eval_Mode2.T)
print(eval_Mode2.P)
# Out:
# (0.15384615384615385, 0.15384615384615385)
# 4
# 26
# 26

# %%
purity = purity_score(df['cluster_id'].to_numpy(), labels2)
AMI = sklearn.metrics.adjusted_mutual_info_score(df['cluster_id'].to_numpy(), labels2)
RAND = sklearn.metrics.adjusted_rand_score(df['cluster_id'].to_numpy(), labels2)
print(purity, AMI, RAND)
# Out:
# 0.5397 0.23984724945599692 0.08078137061368719

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
label_names = np.array([f'cluster {id}' for id in labels2])
sns.scatterplot(data=df, ax=axes[0,0], x='lzstar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,1], x='lystar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='jzstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='jrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,2], x='feH', y='mgfe', hue=label_names)
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
from collections import Counter
print(Counter(df['cluster_id'].to_numpy()))
# Out:
# Counter({22: 3716, 15: 1495, 18: 1230, 20: 1124, 3: 616, 8: 587, 10: 288, 25: 176, 11: 135, 16: 133, 6: 127, 24: 100, 9: 64, 17: 61, 23: 35, 2: 23, 26: 16, 21: 13, 13: 10, 14: 10, 19: 9, 1: 9, 7: 8, 12: 7, 4: 6, 5: 2})

# %%
df = pd.read_hdf('../data/m12f_cluster_data_large_mass_large_cluster_v2.h5', key='star')
easy_small_clusters = [23, 2, 26, 4]
df = df.loc[np.isin(df['cluster_id'], easy_small_clusters)].copy()
df['lstar'] = np.linalg.norm([df['lzstar'].to_numpy(),df['lystar'].to_numpy(),df['lxstar'].to_numpy()],axis=0)
df['cluster_id_name'] = np.array([f'cluster {id}' for id in df['cluster_id'].to_numpy()])
df['c_lzstar'] = df['lzstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lystar'] = df['lystar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lxstar'] = df['lxstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['s_jzrstar'] = df['jzstar'].to_numpy() - df['jrstar'].to_numpy() # mostly spherical because you can try squaring it
df['a_jzrstar'] = df['jzstar'].to_numpy() + df['jrstar'].to_numpy() # mostly spherical because you can try squaring it
df['rstar'] = np.linalg.norm([df['xstar'].to_numpy(),df['ystar'].to_numpy(),df['zstar'].to_numpy()],axis=0)

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.scatterplot(data=df, ax=axes[0,0], x='lzstar', y='estar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[0,1], x='lystar', y='estar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='jzstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='jrstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,2], x='vxstar', y='vphistar', hue='cluster_id_name')
plt.show()

# %%
selected_columns=['estar', 'c_lzstar', 'c_lxstar', 'c_lystar', 's_jzrstar', 'a_jzrstar', 'jphistar', 'eccstar', 'rstar', 'feH', 'mgfe', 'zmaxstar']
#clusterer = C_HDBSCAN(metric='euclidean', min_cluster_size=40, min_samples=15, cluster_selection_method='leaf', cluster_selection_epsilon=0.01)
clusterer = C_GaussianMixture(n_components=6)
clusterer.add_data(df, columns=selected_columns)
clusters = clusterer.fit()

# %%
eval_IoU1 = ClusterEvalIoU(clusters, df['cluster_id'].to_numpy())
print(eval_IoU1())
print(eval_IoU1.TP)
print(eval_IoU1.T)
print(eval_IoU1.P)
# Out:
# (0.3333333333333333, 0.5)
# 2
# 4
# 6

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
clusters_names = [f'cluster {label}' for label in clusters]
sns.scatterplot(data=df, ax=axes[0,0], x='lzstar', y='estar', hue=clusters_names)
sns.scatterplot(data=df, ax=axes[0,1], x='lystar', y='estar', hue=clusters_names)
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue=clusters_names)
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='jzstar', hue=clusters_names)
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='jrstar', hue=clusters_names)
sns.scatterplot(data=df, ax=axes[1,2], x='vxstar', y='vphistar', hue=clusters_names)
plt.show()

# %%
from collections import Counter
print(len(chosen_ids))
Counter(label_names[chosen_ids]).most_common()
# Out:
# 8223
# [('cluster -1', 5419),
#  ('cluster 616', 42),
#  ('cluster 580', 33),
#  ('cluster 582', 31),
#  ('cluster 585', 29),
#  ('cluster 360', 28),
#  ('cluster 622', 27),
#  ('cluster 739', 24),
#  ('cluster 574', 24),
#  ('cluster 351', 23),
#  ('cluster 492', 22),
#  ('cluster 79', 21),
#  ('cluster 493', 20),
#  ('cluster 656', 19),
#  ('cluster 665', 19),
#  ('cluster 604', 19),
#  ('cluster 612', 19),
#  ('cluster 205', 18),
#  ('cluster 650', 18),
#  ('cluster 666', 18),
#  ('cluster 684', 18),
#  ('cluster 609', 18),
#  ('cluster 531', 18),
#  ('cluster 503', 17),
#  ('cluster 754', 17),
#  ('cluster 345', 17),
#  ('cluster 623', 17),
#  ('cluster 564', 17),
#  ('cluster 683', 16),
#  ('cluster 318', 16),
#  ('cluster 527', 16),
#  ('cluster 738', 16),
#  ('cluster 710', 15),
#  ('cluster 680', 15),
#  ('cluster 619', 15),
#  ('cluster 583', 15),
#  ('cluster 649', 15),
#  ('cluster 740', 15),
#  ('cluster 523', 15),
#  ('cluster 594', 15),
#  ('cluster 10', 14),
#  ('cluster 729', 14),
#  ('cluster 692', 14),
#  ('cluster 640', 14),
#  ('cluster 615', 14),
#  ('cluster 59', 14),
#  ('cluster 488', 14),
#  ('cluster 542', 14),
#  ('cluster 498', 13),
#  ('cluster 703', 13),
#  ('cluster 543', 13),
#  ('cluster 726', 13),
#  ('cluster 741', 13),
#  ('cluster 713', 13),
#  ('cluster 672', 13),
#  ('cluster 576', 13),
#  ('cluster 414', 13),
#  ('cluster 556', 13),
#  ('cluster 714', 12),
#  ('cluster 526', 12),
#  ('cluster 724', 12),
#  ('cluster 549', 12),
#  ('cluster 581', 12),
#  ('cluster 347', 12),
#  ('cluster 335', 12),
#  ('cluster 561', 12),
#  ('cluster 749', 12),
#  ('cluster 522', 12),
#  ('cluster 610', 12),
#  ('cluster 563', 12),
#  ('cluster 538', 12),
#  ('cluster 725', 11),
#  ('cluster 689', 11),
#  ('cluster 553', 11),
#  ('cluster 694', 11),
#  ('cluster 548', 11),
#  ('cluster 698', 11),
#  ('cluster 23', 11),
#  ('cluster 537', 11),
#  ('cluster 747', 11),
#  ('cluster 350', 11),
#  ('cluster 237', 11),
#  ('cluster 624', 11),
#  ('cluster 484', 11),
#  ('cluster 566', 11),
#  ('cluster 617', 11),
#  ('cluster 600', 11),
#  ('cluster 611', 11),
#  ('cluster 577', 11),
#  ('cluster 555', 11),
#  ('cluster 539', 11),
#  ('cluster 147', 11),
#  ('cluster 480', 10),
#  ('cluster 22', 10),
#  ('cluster 664', 10),
#  ('cluster 730', 10),
#  ('cluster 736', 10),
#  ('cluster 706', 10),
#  ('cluster 643', 10),
#  ('cluster 744', 10),
#  ('cluster 748', 10),
#  ('cluster 732', 10),
#  ('cluster 711', 10),
#  ('cluster 733', 10),
#  ('cluster 337', 10),
#  ('cluster 291', 10),
#  ('cluster 530', 10),
#  ('cluster 550', 10),
#  ('cluster 496', 10),
#  ('cluster 185', 10),
#  ('cluster 262', 10),
#  ('cluster 490', 10),
#  ('cluster 608', 10),
#  ('cluster 529', 10),
#  ('cluster 452', 9),
#  ('cluster 728', 9),
#  ('cluster 625', 9),
#  ('cluster 731', 9),
#  ('cluster 675', 9),
#  ('cluster 718', 9),
#  ('cluster 715', 9),
#  ('cluster 753', 9),
#  ('cluster 717', 9),
#  ('cluster 562', 9),
#  ('cluster 544', 9),
#  ('cluster 690', 9),
#  ('cluster 479', 9),
#  ('cluster 546', 9),
#  ('cluster 409', 9),
#  ('cluster 572', 9),
#  ('cluster 620', 9),
#  ('cluster 153', 9),
#  ('cluster 628', 9),
#  ('cluster 657', 8),
#  ('cluster 551', 8),
#  ('cluster 686', 8),
#  ('cluster 752', 8),
#  ('cluster 688', 8),
#  ('cluster 599', 8),
#  ('cluster 501', 8),
#  ('cluster 743', 8),
#  ('cluster 508', 8),
#  ('cluster 722', 8),
#  ('cluster 708', 8),
#  ('cluster 737', 8),
#  ('cluster 352', 8),
#  ('cluster 697', 8),
#  ('cluster 520', 8),
#  ('cluster 676', 8),
#  ('cluster 558', 8),
#  ('cluster 685', 8),
#  ('cluster 497', 8),
#  ('cluster 592', 8),
#  ('cluster 598', 8),
#  ('cluster 521', 8),
#  ('cluster 557', 8),
#  ('cluster 602', 8),
#  ('cluster 605', 8),
#  ('cluster 184', 8),
#  ('cluster 77', 8),
#  ('cluster 16', 7),
#  ('cluster 633', 7),
#  ('cluster 477', 7),
#  ('cluster 587', 7),
#  ('cluster 669', 7),
#  ('cluster 709', 7),
#  ('cluster 146', 7),
#  ('cluster 745', 7),
#  ('cluster 746', 7),
#  ('cluster 636', 7),
#  ('cluster 370', 7),
#  ('cluster 696', 7),
#  ('cluster 632', 7),
#  ('cluster 720', 7),
#  ('cluster 630', 7),
#  ('cluster 679', 7),
#  ('cluster 169', 7),
#  ('cluster 661', 7),
#  ('cluster 670', 7),
#  ('cluster 734', 7),
#  ('cluster 645', 7),
#  ('cluster 499', 7),
#  ('cluster 606', 7),
#  ('cluster 487', 7),
#  ('cluster 532', 7),
#  ('cluster 573', 7),
#  ('cluster 565', 7),
#  ('cluster 639', 7),
#  ('cluster 603', 7),
#  ('cluster 528', 7),
#  ('cluster 519', 7),
#  ('cluster 399', 7),
#  ('cluster 513', 7),
#  ('cluster 453', 7),
#  ('cluster 652', 7),
#  ('cluster 595', 7),
#  ('cluster 536', 7),
#  ('cluster 568', 7),
#  ('cluster 554', 7),
#  ('cluster 559', 7),
#  ('cluster 541', 7),
#  ('cluster 613', 6),
#  ('cluster 593', 6),
#  ('cluster 359', 6),
#  ('cluster 750', 6),
#  ('cluster 651', 6),
#  ('cluster 369', 6),
#  ('cluster 682', 6),
#  ('cluster 590', 6),
#  ('cluster 346', 6),
#  ('cluster 705', 6),
#  ('cluster 719', 6),
#  ('cluster 305', 6),
#  ('cluster 618', 6),
#  ('cluster 677', 6),
#  ('cluster 227', 6),
#  ('cluster 673', 6),
#  ('cluster 663', 6),
#  ('cluster 735', 6),
#  ('cluster 512', 6),
#  ('cluster 475', 6),
#  ('cluster 55', 6),
#  ('cluster 700', 6),
#  ('cluster 638', 6),
#  ('cluster 716', 6),
#  ('cluster 751', 6),
#  ('cluster 687', 6),
#  ('cluster 674', 6),
#  ('cluster 727', 6),
#  ('cluster 516', 6),
#  ('cluster 524', 6),
#  ('cluster 502', 6),
#  ('cluster 681', 6),
#  ('cluster 63', 6),
#  ('cluster 560', 6),
#  ('cluster 174', 6),
#  ('cluster 515', 6),
#  ('cluster 486', 6),
#  ('cluster 545', 6),
#  ('cluster 491', 6),
#  ('cluster 601', 6),
#  ('cluster 500', 6),
#  ('cluster 525', 6),
#  ('cluster 637', 6),
#  ('cluster 607', 6),
#  ('cluster 570', 6),
#  ('cluster 584', 6),
#  ('cluster 578', 6),
#  ('cluster 540', 6),
#  ('cluster 221', 6),
#  ('cluster 225', 6),
#  ('cluster 588', 6),
#  ('cluster 533', 6),
#  ('cluster 167', 6),
#  ('cluster 671', 5),
#  ('cluster 575', 5),
#  ('cluster 222', 5),
#  ('cluster 634', 3),
#  ('cluster 884', 2),
#  ('cluster 569', 2),
#  ('cluster 19', 2),
#  ('cluster 14', 2),
#  ('cluster 130', 2),
#  ('cluster 654', 2),
#  ('cluster 355', 2),
#  ('cluster 21', 2),
#  ('cluster 157', 2),
#  ('cluster 3268', 1),
#  ('cluster 2930', 1),
#  ('cluster 2677', 1),
#  ('cluster 107', 1),
#  ('cluster 844', 1),
#  ('cluster 1298', 1),
#  ('cluster 3463', 1),
#  ('cluster 277', 1),
#  ('cluster 1320', 1),
#  ('cluster 431', 1),
#  ('cluster 66', 1),
#  ('cluster 3100', 1),
#  ('cluster 2233', 1),
#  ('cluster 3556', 1),
#  ('cluster 509', 1),
#  ('cluster 411', 1),
#  ('cluster 161', 1),
#  ('cluster 2358', 1),
#  ('cluster 571', 1),
#  ('cluster 3729', 1),
#  ('cluster 2842', 1),
#  ('cluster 82', 1),
#  ('cluster 1586', 1),
#  ('cluster 1849', 1),
#  ('cluster 89', 1),
#  ('cluster 1070', 1),
#  ('cluster 1676', 1),
#  ('cluster 507', 1),
#  ('cluster 937', 1),
#  ('cluster 1982', 1),
#  ('cluster 919', 1),
#  ('cluster 1799', 1),
#  ('cluster 1096', 1),
#  ('cluster 3156', 1),
#  ('cluster 962', 1),
#  ('cluster 897', 1),
#  ('cluster 1960', 1),
#  ('cluster 2378', 1),
#  ('cluster 2773', 1),
#  ('cluster 2431', 1),
#  ('cluster 2276', 1),
#  ('cluster 68', 1),
#  ('cluster 2259', 1),
#  ('cluster 102', 1),
#  ('cluster 65', 1),
#  ('cluster 2006', 1),
#  ('cluster 2569', 1),
#  ('cluster 2399', 1),
#  ('cluster 1168', 1),
#  ('cluster 300', 1),
#  ('cluster 3688', 1),
#  ('cluster 2760', 1),
#  ('cluster 4525', 1),
#  ('cluster 828', 1),
#  ('cluster 1995', 1),
#  ('cluster 1367', 1),
#  ('cluster 3662', 1),
#  ('cluster 1704', 1),
#  ('cluster 3537', 1),
#  ('cluster 1457', 1),
#  ('cluster 1059', 1),
#  ('cluster 806', 1),
#  ('cluster 3425', 1),
#  ('cluster 1833', 1),
#  ('cluster 3661', 1),
#  ('cluster 2175', 1),
#  ('cluster 11', 1),
#  ('cluster 1313', 1),
#  ('cluster 1513', 1),
#  ('cluster 4333', 1),
#  ('cluster 1497', 1),
#  ('cluster 4138', 1),
#  ('cluster 188', 1),
#  ('cluster 898', 1),
#  ('cluster 3288', 1),
#  ('cluster 3827', 1),
#  ('cluster 2170', 1),
#  ('cluster 2879', 1),
#  ('cluster 1075', 1),
#  ('cluster 2152', 1),
#  ('cluster 755', 1),
#  ('cluster 3978', 1),
#  ('cluster 627', 1),
#  ('cluster 2449', 1),
#  ('cluster 874', 1),
#  ('cluster 316', 1),
#  ('cluster 852', 1),
#  ('cluster 1441', 1),
#  ('cluster 2538', 1),
#  ('cluster 932', 1),
#  ('cluster 1959', 1),
#  ('cluster 3059', 1),
#  ('cluster 4514', 1),
#  ('cluster 2715', 1),
#  ('cluster 2625', 1),
#  ('cluster 164', 1),
#  ('cluster 4428', 1),
#  ('cluster 2574', 1),
#  ('cluster 1148', 1),
#  ('cluster 3907', 1),
#  ('cluster 2248', 1),
#  ('cluster 268', 1),
#  ('cluster 2992', 1),
#  ('cluster 2293', 1),
#  ('cluster 3297', 1),
#  ('cluster 3484', 1),
#  ('cluster 1761', 1),
#  ('cluster 3285', 1),
#  ('cluster 2653', 1),
#  ('cluster 1116', 1),
#  ('cluster 2753', 1),
#  ('cluster 88', 1),
#  ('cluster 4119', 1),
#  ('cluster 2088', 1),
#  ('cluster 1272', 1),
#  ('cluster 111', 1),
#  ('cluster 2668', 1),
#  ('cluster 2213', 1),
#  ('cluster 3627', 1),
#  ('cluster 3690', 1),
#  ('cluster 3709', 1),
#  ('cluster 826', 1),
#  ('cluster 2468', 1),
#  ('cluster 1931', 1),
#  ('cluster 4080', 1),
#  ('cluster 1872', 1),
#  ('cluster 4215', 1),
#  ('cluster 1222', 1),
#  ('cluster 30', 1),
#  ('cluster 4486', 1),
#  ('cluster 4314', 1),
#  ('cluster 2493', 1),
#  ('cluster 1446', 1),
#  ('cluster 2591', 1),
#  ('cluster 4364', 1),
#  ('cluster 1484', 1),
#  ('cluster 3307', 1),
#  ('cluster 2643', 1),
#  ('cluster 298', 1),
#  ('cluster 1729', 1),
#  ('cluster 3821', 1),
#  ('cluster 234', 1),
#  ('cluster 2925', 1),
#  ('cluster 998', 1),
#  ('cluster 2675', 1),
#  ('cluster 1876', 1),
#  ('cluster 12', 1),
#  ('cluster 1083', 1),
#  ('cluster 483', 1),
#  ('cluster 349', 1)]

# %%
from sklearn import metrics

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels)
# Out:
# 0.5088605084460291

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy())
print(eval_IoU1())
print(eval_IoU1.TP)
# Out:
# (7.333333333333333, 0.44)
# 22

# %%
print(eval_IoU1.P)
# Out:
# 3

# %% [markdown]
# ### Now let's test out recursive clustering

# %%
clustera = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
clusterb = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
cluster2 = RecursiveCluster(subspace1_clusterer=clustera, subspace2_clusterer=clusterb)
cluster2.config()

# %%
cluster2.add_data(df, subspace1=['feH','mgfe'], subspace2=['feH','mgfe'])

# %%
labels2 = cluster2.fit()
# Out:
# [0 0 0 ... 0 0 0]
# [29429   166    -1 ... 34129 16868 37740]
# 44066
# 44066
# [   -1   166    -1 ...    -1    -1 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066

# %%
print(labels2)
label2_names = np.array([f'cluster {label}' for label in labels2])
labels_sorted = np.sort(labels2)
print(labels_sorted)
# Out:
# [   -1    -1  7579 ... 43818    -1 48470]
# [   -1    -1    -1 ... 51662 51663 51663]

# %%
chosen_ids = np.argwhere(df['cluster_id'].isin(chosen_cluster_ids).to_numpy())[:,0]

# %%
#sns.scatterplot(data=df.iloc[chosen_ids], x='feH', y='mgfe', hue=label2_names[chosen_ids])

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels2)
# Out:
# 0.7065505895246961

# %%
metrics.rand_score(labels, labels2)
# Out:
# 0.1470609716211652

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy())
print(eval_IoU1())
# Out:
# (7.333333333333333, 0.44)

# %%
eval_IoU2 = ClusterEvalIoU(labels2, df['cluster_id'].to_numpy())
print(eval_IoU2())
# Out:
# (1.9355463079454177e-05, 0.02)

# %%
eval_IoU3 = ClusterEvalIoU(labels, labels2)
print(eval_IoU3())
# Out:
# (71.33333333333333, 0.004142069099003194)

# %% [markdown]
# ### Now let's test HDBSCAN + GMM

# %%
clustera = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
clusterb = C_GaussianMixture(n_components=1)
cluster3 = RecursiveCluster(subspace1_clusterer=clustera, subspace2_clusterer=clusterb)
cluster3.config()
cluster3.add_data(df, subspace1=['feH','mgfe'], subspace2=['feH','mgfe'])

# %%
labels3 = cluster3.fit()
# Out:
# [0 0 0 ... 0 0 0]
# [29429   166    -1 ... 34129 16868 37740]
# 44066
# 44066
# [29429   166    -1 ... 34129 16868 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066
# [   -1   166    -1 ...    -1    -1 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels3)
# Out:
# 0.681046828478812

# %%
eval_IoU4 = ClusterEvalIoU(labels3, df['cluster_id'].to_numpy())
print(eval_IoU4())
# Out:
# (2.26927179068237e-05, 0.02)
