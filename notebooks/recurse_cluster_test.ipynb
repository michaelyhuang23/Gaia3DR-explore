# %%
import sys
sys.path.append('..')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from cluster_analysis import C_HDBSCAN, C_GaussianMixture
from evaluation_metrics import ClusterEvalIoU
from recurse_cluster import RecursiveCluster
from pingouin import multivariate_normality

# %%
df = pd.read_hdf('../data/m12i_cluster_data_large_mass_large_cluster_v2.h5', key='star')
df['cluster_id_name'] = np.array([f'cluster {id}' for id in df['cluster_id'].to_numpy()])
chosen_cluster_ids = np.random.choice(np.arange(1,27), 26, replace=False)
chosen_ids = np.argwhere(df['cluster_id'].isin(chosen_cluster_ids).to_numpy())[:,0]
chosen_ids = np.random.choice(chosen_ids, min(len(chosen_ids), 10000))
df = df.iloc[chosen_ids].copy()
df = df.reset_index()
df.head()
# Out:
#     index  Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1       feH  id_stars  \
# 0  117508        117508      117508        117508 -2.329406   7114648
# 1  126620        126620      126620        126620 -1.373449    672571
# 2  145695        145695      145695        145695 -2.099548   9155759
# 3  148361        148361      148361        148361 -2.079607  10192630
# 4   48514         48514       48514         48514 -1.619282  13080705
#
#    radial_distance_stars  redshift_stars  snap_list_stars    star_mass  ...  \
# 0               9.001316        2.505618              142  4433.734848  ...
# 1               1.701884        3.000000              120  4857.426421  ...
# 2               4.555006        3.000000              120  4777.892599  ...
# 3              10.166078        3.000000              120  4975.825108  ...
# 4              11.791748        1.500000              214  4914.354052  ...
#
#            pstar         kstar      lxstar      lystar      lzstar    apostar  \
# 0 -138213.691924  28173.741622   -8.532709  575.927100  278.661933  15.931228
# 1 -248027.199884  32967.828780 -347.866155  114.601929 -195.026695   2.244793
# 2 -183858.138267  10837.847471  296.638435 -270.578115 -507.776549   4.656638
# 3 -132637.401470   9420.290923  707.165152  436.894864  486.518933  11.599922
# 4 -128014.083858  42616.845709   34.966332  368.454923 -776.269227  29.062460
#
#    peristar   eccstar   zmaxstar  cluster_id_name
# 0  1.309592  0.848082  13.969688       cluster 23
# 1  0.936984  0.411031   1.724648       cluster 18
# 2  1.473965  0.519145   2.433368       cluster 18
# 3  2.432511  0.653302   9.701991       cluster 18
# 4  1.518140  0.900712  13.716486       cluster 25
#
# [5 rows x 53 columns]

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
df['lstar'] = np.linalg.norm([df['lzstar'].to_numpy(),df['lystar'].to_numpy(),df['lxstar'].to_numpy()],axis=0)
df['c_lzstar'] = df['lzstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lystar'] = df['lystar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['c_lxstar'] = df['lxstar'].to_numpy()*np.abs(df['estar'].to_numpy())**2.3
df['s_jzrstar'] = df['jzstar'].to_numpy() - df['jrstar'].to_numpy() # mostly spherical because you can try squaring it
df['a_jzrstar'] = df['jzstar'].to_numpy() + df['jrstar'].to_numpy() # mostly spherical because you can try squaring it
df['rstar'] = np.linalg.norm([df['xstar'].to_numpy(),df['ystar'].to_numpy(),df['zstar'].to_numpy()],axis=0)
sns.scatterplot(data=df, ax=axes[0,0], x='lzstar', y='estar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[0,1], x='lystar', y='estar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='jzstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='jrstar', hue='cluster_id_name')
sns.scatterplot(data=df, ax=axes[1,2], x='vxstar', y='vphistar', hue='cluster_id_name')
# Out:
# <AxesSubplot:xlabel='vxstar', ylabel='vphistar'>

# %%
cluster1 = C_HDBSCAN(metric='euclidean', min_cluster_size=4, min_samples=4, cluster_selection_method='leaf', cluster_selection_epsilon=0.01)
cluster1.config()
# action diamond

# %%
selected_columns=['estar', 'c_lzstar', 'c_lxstar', 'c_lystar', 's_jzrstar', 'a_jzrstar', 'jphistar', 'eccstar', 'rstar', 'feH', 'mgfe', 'zmaxstar']

# %%
cluster1.add_data(df, columns=selected_columns)
labels = cluster1.fit()

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy())
print(eval_IoU1())
print(eval_IoU1.TP)
print(eval_IoU1.T)
print(eval_IoU1.P)
# IoU metric makes no sense when the cutoff is below 0.5
# Out:
# (0.0, 0.0)
# 0
# 26
# 133

# %%
df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0', 'Unnamed: 0.1'])
df.index.is_unique
# Out:
# True

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.kdeplot(data=df, ax=axes[0,0], x='c_lzstar', y='estar')
sns.kdeplot(data=df, ax=axes[0,1], x='c_lystar', y='estar')
sns.kdeplot(data=df, ax=axes[0,2], x='rstar', y='eccstar')
sns.kdeplot(data=df, ax=axes[1,0], x='jphistar', y='s_jzrstar')
sns.kdeplot(data=df, ax=axes[1,1], x='jphistar', y='a_jzrstar')
sns.kdeplot(data=df, ax=axes[1,2], x='feH', y='mgfe')
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
label_names = np.array([f'cluster {id}' for id in labels])
sns.scatterplot(data=df, ax=axes[0,0], x='c_lzstar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,1], x='c_lystar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='s_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='a_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,2], x='feH', y='mgfe', hue=label_names)
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
cluster2 = C_GaussianMixture(n_components=100)

# %%
cluster2.add_data(df, columns=selected_columns)
labels2 = cluster2.fit(epoch = 100)

# %%
eval_IoU2 = ClusterEvalIoU(labels2, df['cluster_id'].to_numpy())
print(eval_IoU2())
print(eval_IoU2.TP)
print(eval_IoU2.T)
print(eval_IoU2.P)
# Out:
# (0.0, 0.0)
# 0
# 26
# 100

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
label_names = np.array([f'cluster {id}' for id in labels2])
sns.scatterplot(data=df, ax=axes[0,0], x='c_lzstar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,1], x='c_lystar', y='estar', hue=label_names)
sns.scatterplot(data=df, ax=axes[0,2], x='rstar', y='eccstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,0], x='jphistar', y='s_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,1], x='jphistar', y='a_jzrstar', hue=label_names)
sns.scatterplot(data=df, ax=axes[1,2], x='feH', y='mgfe', hue=label_names)
# Out:
# <AxesSubplot:xlabel='feH', ylabel='mgfe'>

# %%
from collections import Counter
print(len(chosen_ids))
Counter(label_names[chosen_ids]).most_common()
# Out:
# 8223
# [('cluster -1', 5419),
#  ('cluster 616', 42),
#  ('cluster 580', 33),
#  ('cluster 582', 31),
#  ('cluster 585', 29),
#  ('cluster 360', 28),
#  ('cluster 622', 27),
#  ('cluster 739', 24),
#  ('cluster 574', 24),
#  ('cluster 351', 23),
#  ('cluster 492', 22),
#  ('cluster 79', 21),
#  ('cluster 493', 20),
#  ('cluster 656', 19),
#  ('cluster 665', 19),
#  ('cluster 604', 19),
#  ('cluster 612', 19),
#  ('cluster 205', 18),
#  ('cluster 650', 18),
#  ('cluster 666', 18),
#  ('cluster 684', 18),
#  ('cluster 609', 18),
#  ('cluster 531', 18),
#  ('cluster 503', 17),
#  ('cluster 754', 17),
#  ('cluster 345', 17),
#  ('cluster 623', 17),
#  ('cluster 564', 17),
#  ('cluster 683', 16),
#  ('cluster 318', 16),
#  ('cluster 527', 16),
#  ('cluster 738', 16),
#  ('cluster 710', 15),
#  ('cluster 680', 15),
#  ('cluster 619', 15),
#  ('cluster 583', 15),
#  ('cluster 649', 15),
#  ('cluster 740', 15),
#  ('cluster 523', 15),
#  ('cluster 594', 15),
#  ('cluster 10', 14),
#  ('cluster 729', 14),
#  ('cluster 692', 14),
#  ('cluster 640', 14),
#  ('cluster 615', 14),
#  ('cluster 59', 14),
#  ('cluster 488', 14),
#  ('cluster 542', 14),
#  ('cluster 498', 13),
#  ('cluster 703', 13),
#  ('cluster 543', 13),
#  ('cluster 726', 13),
#  ('cluster 741', 13),
#  ('cluster 713', 13),
#  ('cluster 672', 13),
#  ('cluster 576', 13),
#  ('cluster 414', 13),
#  ('cluster 556', 13),
#  ('cluster 714', 12),
#  ('cluster 526', 12),
#  ('cluster 724', 12),
#  ('cluster 549', 12),
#  ('cluster 581', 12),
#  ('cluster 347', 12),
#  ('cluster 335', 12),
#  ('cluster 561', 12),
#  ('cluster 749', 12),
#  ('cluster 522', 12),
#  ('cluster 610', 12),
#  ('cluster 563', 12),
#  ('cluster 538', 12),
#  ('cluster 725', 11),
#  ('cluster 689', 11),
#  ('cluster 553', 11),
#  ('cluster 694', 11),
#  ('cluster 548', 11),
#  ('cluster 698', 11),
#  ('cluster 23', 11),
#  ('cluster 537', 11),
#  ('cluster 747', 11),
#  ('cluster 350', 11),
#  ('cluster 237', 11),
#  ('cluster 624', 11),
#  ('cluster 484', 11),
#  ('cluster 566', 11),
#  ('cluster 617', 11),
#  ('cluster 600', 11),
#  ('cluster 611', 11),
#  ('cluster 577', 11),
#  ('cluster 555', 11),
#  ('cluster 539', 11),
#  ('cluster 147', 11),
#  ('cluster 480', 10),
#  ('cluster 22', 10),
#  ('cluster 664', 10),
#  ('cluster 730', 10),
#  ('cluster 736', 10),
#  ('cluster 706', 10),
#  ('cluster 643', 10),
#  ('cluster 744', 10),
#  ('cluster 748', 10),
#  ('cluster 732', 10),
#  ('cluster 711', 10),
#  ('cluster 733', 10),
#  ('cluster 337', 10),
#  ('cluster 291', 10),
#  ('cluster 530', 10),
#  ('cluster 550', 10),
#  ('cluster 496', 10),
#  ('cluster 185', 10),
#  ('cluster 262', 10),
#  ('cluster 490', 10),
#  ('cluster 608', 10),
#  ('cluster 529', 10),
#  ('cluster 452', 9),
#  ('cluster 728', 9),
#  ('cluster 625', 9),
#  ('cluster 731', 9),
#  ('cluster 675', 9),
#  ('cluster 718', 9),
#  ('cluster 715', 9),
#  ('cluster 753', 9),
#  ('cluster 717', 9),
#  ('cluster 562', 9),
#  ('cluster 544', 9),
#  ('cluster 690', 9),
#  ('cluster 479', 9),
#  ('cluster 546', 9),
#  ('cluster 409', 9),
#  ('cluster 572', 9),
#  ('cluster 620', 9),
#  ('cluster 153', 9),
#  ('cluster 628', 9),
#  ('cluster 657', 8),
#  ('cluster 551', 8),
#  ('cluster 686', 8),
#  ('cluster 752', 8),
#  ('cluster 688', 8),
#  ('cluster 599', 8),
#  ('cluster 501', 8),
#  ('cluster 743', 8),
#  ('cluster 508', 8),
#  ('cluster 722', 8),
#  ('cluster 708', 8),
#  ('cluster 737', 8),
#  ('cluster 352', 8),
#  ('cluster 697', 8),
#  ('cluster 520', 8),
#  ('cluster 676', 8),
#  ('cluster 558', 8),
#  ('cluster 685', 8),
#  ('cluster 497', 8),
#  ('cluster 592', 8),
#  ('cluster 598', 8),
#  ('cluster 521', 8),
#  ('cluster 557', 8),
#  ('cluster 602', 8),
#  ('cluster 605', 8),
#  ('cluster 184', 8),
#  ('cluster 77', 8),
#  ('cluster 16', 7),
#  ('cluster 633', 7),
#  ('cluster 477', 7),
#  ('cluster 587', 7),
#  ('cluster 669', 7),
#  ('cluster 709', 7),
#  ('cluster 146', 7),
#  ('cluster 745', 7),
#  ('cluster 746', 7),
#  ('cluster 636', 7),
#  ('cluster 370', 7),
#  ('cluster 696', 7),
#  ('cluster 632', 7),
#  ('cluster 720', 7),
#  ('cluster 630', 7),
#  ('cluster 679', 7),
#  ('cluster 169', 7),
#  ('cluster 661', 7),
#  ('cluster 670', 7),
#  ('cluster 734', 7),
#  ('cluster 645', 7),
#  ('cluster 499', 7),
#  ('cluster 606', 7),
#  ('cluster 487', 7),
#  ('cluster 532', 7),
#  ('cluster 573', 7),
#  ('cluster 565', 7),
#  ('cluster 639', 7),
#  ('cluster 603', 7),
#  ('cluster 528', 7),
#  ('cluster 519', 7),
#  ('cluster 399', 7),
#  ('cluster 513', 7),
#  ('cluster 453', 7),
#  ('cluster 652', 7),
#  ('cluster 595', 7),
#  ('cluster 536', 7),
#  ('cluster 568', 7),
#  ('cluster 554', 7),
#  ('cluster 559', 7),
#  ('cluster 541', 7),
#  ('cluster 613', 6),
#  ('cluster 593', 6),
#  ('cluster 359', 6),
#  ('cluster 750', 6),
#  ('cluster 651', 6),
#  ('cluster 369', 6),
#  ('cluster 682', 6),
#  ('cluster 590', 6),
#  ('cluster 346', 6),
#  ('cluster 705', 6),
#  ('cluster 719', 6),
#  ('cluster 305', 6),
#  ('cluster 618', 6),
#  ('cluster 677', 6),
#  ('cluster 227', 6),
#  ('cluster 673', 6),
#  ('cluster 663', 6),
#  ('cluster 735', 6),
#  ('cluster 512', 6),
#  ('cluster 475', 6),
#  ('cluster 55', 6),
#  ('cluster 700', 6),
#  ('cluster 638', 6),
#  ('cluster 716', 6),
#  ('cluster 751', 6),
#  ('cluster 687', 6),
#  ('cluster 674', 6),
#  ('cluster 727', 6),
#  ('cluster 516', 6),
#  ('cluster 524', 6),
#  ('cluster 502', 6),
#  ('cluster 681', 6),
#  ('cluster 63', 6),
#  ('cluster 560', 6),
#  ('cluster 174', 6),
#  ('cluster 515', 6),
#  ('cluster 486', 6),
#  ('cluster 545', 6),
#  ('cluster 491', 6),
#  ('cluster 601', 6),
#  ('cluster 500', 6),
#  ('cluster 525', 6),
#  ('cluster 637', 6),
#  ('cluster 607', 6),
#  ('cluster 570', 6),
#  ('cluster 584', 6),
#  ('cluster 578', 6),
#  ('cluster 540', 6),
#  ('cluster 221', 6),
#  ('cluster 225', 6),
#  ('cluster 588', 6),
#  ('cluster 533', 6),
#  ('cluster 167', 6),
#  ('cluster 671', 5),
#  ('cluster 575', 5),
#  ('cluster 222', 5),
#  ('cluster 634', 3),
#  ('cluster 884', 2),
#  ('cluster 569', 2),
#  ('cluster 19', 2),
#  ('cluster 14', 2),
#  ('cluster 130', 2),
#  ('cluster 654', 2),
#  ('cluster 355', 2),
#  ('cluster 21', 2),
#  ('cluster 157', 2),
#  ('cluster 3268', 1),
#  ('cluster 2930', 1),
#  ('cluster 2677', 1),
#  ('cluster 107', 1),
#  ('cluster 844', 1),
#  ('cluster 1298', 1),
#  ('cluster 3463', 1),
#  ('cluster 277', 1),
#  ('cluster 1320', 1),
#  ('cluster 431', 1),
#  ('cluster 66', 1),
#  ('cluster 3100', 1),
#  ('cluster 2233', 1),
#  ('cluster 3556', 1),
#  ('cluster 509', 1),
#  ('cluster 411', 1),
#  ('cluster 161', 1),
#  ('cluster 2358', 1),
#  ('cluster 571', 1),
#  ('cluster 3729', 1),
#  ('cluster 2842', 1),
#  ('cluster 82', 1),
#  ('cluster 1586', 1),
#  ('cluster 1849', 1),
#  ('cluster 89', 1),
#  ('cluster 1070', 1),
#  ('cluster 1676', 1),
#  ('cluster 507', 1),
#  ('cluster 937', 1),
#  ('cluster 1982', 1),
#  ('cluster 919', 1),
#  ('cluster 1799', 1),
#  ('cluster 1096', 1),
#  ('cluster 3156', 1),
#  ('cluster 962', 1),
#  ('cluster 897', 1),
#  ('cluster 1960', 1),
#  ('cluster 2378', 1),
#  ('cluster 2773', 1),
#  ('cluster 2431', 1),
#  ('cluster 2276', 1),
#  ('cluster 68', 1),
#  ('cluster 2259', 1),
#  ('cluster 102', 1),
#  ('cluster 65', 1),
#  ('cluster 2006', 1),
#  ('cluster 2569', 1),
#  ('cluster 2399', 1),
#  ('cluster 1168', 1),
#  ('cluster 300', 1),
#  ('cluster 3688', 1),
#  ('cluster 2760', 1),
#  ('cluster 4525', 1),
#  ('cluster 828', 1),
#  ('cluster 1995', 1),
#  ('cluster 1367', 1),
#  ('cluster 3662', 1),
#  ('cluster 1704', 1),
#  ('cluster 3537', 1),
#  ('cluster 1457', 1),
#  ('cluster 1059', 1),
#  ('cluster 806', 1),
#  ('cluster 3425', 1),
#  ('cluster 1833', 1),
#  ('cluster 3661', 1),
#  ('cluster 2175', 1),
#  ('cluster 11', 1),
#  ('cluster 1313', 1),
#  ('cluster 1513', 1),
#  ('cluster 4333', 1),
#  ('cluster 1497', 1),
#  ('cluster 4138', 1),
#  ('cluster 188', 1),
#  ('cluster 898', 1),
#  ('cluster 3288', 1),
#  ('cluster 3827', 1),
#  ('cluster 2170', 1),
#  ('cluster 2879', 1),
#  ('cluster 1075', 1),
#  ('cluster 2152', 1),
#  ('cluster 755', 1),
#  ('cluster 3978', 1),
#  ('cluster 627', 1),
#  ('cluster 2449', 1),
#  ('cluster 874', 1),
#  ('cluster 316', 1),
#  ('cluster 852', 1),
#  ('cluster 1441', 1),
#  ('cluster 2538', 1),
#  ('cluster 932', 1),
#  ('cluster 1959', 1),
#  ('cluster 3059', 1),
#  ('cluster 4514', 1),
#  ('cluster 2715', 1),
#  ('cluster 2625', 1),
#  ('cluster 164', 1),
#  ('cluster 4428', 1),
#  ('cluster 2574', 1),
#  ('cluster 1148', 1),
#  ('cluster 3907', 1),
#  ('cluster 2248', 1),
#  ('cluster 268', 1),
#  ('cluster 2992', 1),
#  ('cluster 2293', 1),
#  ('cluster 3297', 1),
#  ('cluster 3484', 1),
#  ('cluster 1761', 1),
#  ('cluster 3285', 1),
#  ('cluster 2653', 1),
#  ('cluster 1116', 1),
#  ('cluster 2753', 1),
#  ('cluster 88', 1),
#  ('cluster 4119', 1),
#  ('cluster 2088', 1),
#  ('cluster 1272', 1),
#  ('cluster 111', 1),
#  ('cluster 2668', 1),
#  ('cluster 2213', 1),
#  ('cluster 3627', 1),
#  ('cluster 3690', 1),
#  ('cluster 3709', 1),
#  ('cluster 826', 1),
#  ('cluster 2468', 1),
#  ('cluster 1931', 1),
#  ('cluster 4080', 1),
#  ('cluster 1872', 1),
#  ('cluster 4215', 1),
#  ('cluster 1222', 1),
#  ('cluster 30', 1),
#  ('cluster 4486', 1),
#  ('cluster 4314', 1),
#  ('cluster 2493', 1),
#  ('cluster 1446', 1),
#  ('cluster 2591', 1),
#  ('cluster 4364', 1),
#  ('cluster 1484', 1),
#  ('cluster 3307', 1),
#  ('cluster 2643', 1),
#  ('cluster 298', 1),
#  ('cluster 1729', 1),
#  ('cluster 3821', 1),
#  ('cluster 234', 1),
#  ('cluster 2925', 1),
#  ('cluster 998', 1),
#  ('cluster 2675', 1),
#  ('cluster 1876', 1),
#  ('cluster 12', 1),
#  ('cluster 1083', 1),
#  ('cluster 483', 1),
#  ('cluster 349', 1)]

# %%
from sklearn import metrics

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels)
# Out:
# 0.5088605084460291

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy())
print(eval_IoU1())
print(eval_IoU1.TP)
# Out:
# (7.333333333333333, 0.44)
# 22

# %%
print(eval_IoU1.P)
# Out:
# 3

# %% [markdown]
# ### Now let's test out recursive clustering

# %%
clustera = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
clusterb = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
cluster2 = RecursiveCluster(subspace1_clusterer=clustera, subspace2_clusterer=clusterb)
cluster2.config()

# %%
cluster2.add_data(df, subspace1=['feH','mgfe'], subspace2=['feH','mgfe'])

# %%
labels2 = cluster2.fit()
# Out:
# [0 0 0 ... 0 0 0]
# [29429   166    -1 ... 34129 16868 37740]
# 44066
# 44066
# [   -1   166    -1 ...    -1    -1 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066

# %%
print(labels2)
label2_names = np.array([f'cluster {label}' for label in labels2])
labels_sorted = np.sort(labels2)
print(labels_sorted)
# Out:
# [   -1    -1  7579 ... 43818    -1 48470]
# [   -1    -1    -1 ... 51662 51663 51663]

# %%
chosen_ids = np.argwhere(df['cluster_id'].isin(chosen_cluster_ids).to_numpy())[:,0]

# %%
#sns.scatterplot(data=df.iloc[chosen_ids], x='feH', y='mgfe', hue=label2_names[chosen_ids])

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels2)
# Out:
# 0.7065505895246961

# %%
metrics.rand_score(labels, labels2)
# Out:
# 0.1470609716211652

# %%
eval_IoU1 = ClusterEvalIoU(labels, df['cluster_id'].to_numpy())
print(eval_IoU1())
# Out:
# (7.333333333333333, 0.44)

# %%
eval_IoU2 = ClusterEvalIoU(labels2, df['cluster_id'].to_numpy())
print(eval_IoU2())
# Out:
# (1.9355463079454177e-05, 0.02)

# %%
eval_IoU3 = ClusterEvalIoU(labels, labels2)
print(eval_IoU3())
# Out:
# (71.33333333333333, 0.004142069099003194)

# %% [markdown]
# ### Now let's test HDBSCAN + GMM

# %%
clustera = C_HDBSCAN(metric='euclidean', min_cluster_size=2, min_samples=1, allow_single_cluster=True)
clusterb = C_GaussianMixture(n_components=1)
cluster3 = RecursiveCluster(subspace1_clusterer=clustera, subspace2_clusterer=clusterb)
cluster3.config()
cluster3.add_data(df, subspace1=['feH','mgfe'], subspace2=['feH','mgfe'])

# %%
labels3 = cluster3.fit()
# Out:
# [0 0 0 ... 0 0 0]
# [29429   166    -1 ... 34129 16868 37740]
# 44066
# 44066
# [29429   166    -1 ... 34129 16868 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066
# [   -1   166    -1 ...    -1    -1 37740]
# [   -1   166    -1 ...    -1    -1 37740]
# 44066
# 44066

# %%
metrics.rand_score(df['cluster_id'].to_numpy(), labels3)
# Out:
# 0.681046828478812

# %%
eval_IoU4 = ClusterEvalIoU(labels3, df['cluster_id'].to_numpy())
print(eval_IoU4())
# Out:
# (2.26927179068237e-05, 0.02)
