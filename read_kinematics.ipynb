# %%
import pandas as pd
import numpy as np
import h5py

# %%
df = pd.DataFrame() # Make an empty data frame; you can also use a python dict here 


with h5py.File('./vel_err_orb_err_rvcorr_all.h5','r') as f:
    print(f.keys()) # Print what columns are in the file
    for key in f.keys():
        print(key)
        print(f[key])
        df[key] = np.array(f[key])

df.to_csv('vel_err_orb_err_rvcorr_all.csv')
# Out:
# <KeysViewHDF5 ['Etot', 'JR', 'Jphi', 'Jz', 'KE', 'Lx', 'Ly', 'Lz', 'PE', 'U', 'V', 'W', 'XGC', 'YGC', 'ZGC', 'apo', 'cov_UV', 'cov_UW', 'cov_VW', 'cov_vphiz', 'cov_vrphi', 'cov_vrz', 'e_Etot', 'e_JR', 'e_Jphi', 'e_Jz', 'e_KE', 'e_Lx', 'e_Ly', 'e_Lz', 'e_PE', 'e_U', 'e_V', 'e_W', 'e_XGC', 'e_YGC', 'e_ZGC', 'e_apo', 'e_ecc', 'e_peri', 'e_vphi', 'e_vr', 'e_vz', 'e_zmax', 'ecc', 'f_v_forder', 'parallax_zpcorr', 'peri', 'source_id', 'vphi', 'vr', 'vz', 'zero_point_correction', 'zmax']>
# Etot
# <HDF5 dataset "Etot": shape (33812183,), type "<f8">
# JR
# <HDF5 dataset "JR": shape (33812183,), type "<f8">
# Jphi
# <HDF5 dataset "Jphi": shape (33812183,), type "<f8">
# Jz
# <HDF5 dataset "Jz": shape (33812183,), type "<f8">
# KE
# <HDF5 dataset "KE": shape (33812183,), type "<f8">
# Lx
# <HDF5 dataset "Lx": shape (33812183,), type "<f8">
# Ly
# <HDF5 dataset "Ly": shape (33812183,), type "<f8">
# Lz
# <HDF5 dataset "Lz": shape (33812183,), type "<f8">
# PE
# <HDF5 dataset "PE": shape (33812183,), type "<f8">
# U
# <HDF5 dataset "U": shape (33812183,), type "<f8">
# V
# <HDF5 dataset "V": shape (33812183,), type "<f8">
# W
# <HDF5 dataset "W": shape (33812183,), type "<f8">
# XGC
# <HDF5 dataset "XGC": shape (33812183,), type "<f8">
# YGC
# <HDF5 dataset "YGC": shape (33812183,), type "<f8">
# ZGC
# <HDF5 dataset "ZGC": shape (33812183,), type "<f8">
# apo
# <HDF5 dataset "apo": shape (33812183,), type "<f8">
# cov_UV
# <HDF5 dataset "cov_UV": shape (33812183,), type "<f8">
# cov_UW
# <HDF5 dataset "cov_UW": shape (33812183,), type "<f8">
# cov_VW
# <HDF5 dataset "cov_VW": shape (33812183,), type "<f8">
# cov_vphiz
# <HDF5 dataset "cov_vphiz": shape (33812183,), type "<f8">
# cov_vrphi
# <HDF5 dataset "cov_vrphi": shape (33812183,), type "<f8">
# cov_vrz
# <HDF5 dataset "cov_vrz": shape (33812183,), type "<f8">
# e_Etot
# <HDF5 dataset "e_Etot": shape (33812183,), type "<f8">
# e_JR
# <HDF5 dataset "e_JR": shape (33812183,), type "<f8">
# e_Jphi
# <HDF5 dataset "e_Jphi": shape (33812183,), type "<f8">
# e_Jz
# <HDF5 dataset "e_Jz": shape (33812183,), type "<f8">
# e_KE
# <HDF5 dataset "e_KE": shape (33812183,), type "<f8">
# e_Lx
# <HDF5 dataset "e_Lx": shape (33812183,), type "<f8">
# e_Ly
# <HDF5 dataset "e_Ly": shape (33812183,), type "<f8">
# e_Lz
# <HDF5 dataset "e_Lz": shape (33812183,), type "<f8">
# e_PE
# <HDF5 dataset "e_PE": shape (33812183,), type "<f8">
# e_U
# <HDF5 dataset "e_U": shape (33812183,), type "<f8">
# e_V
# <HDF5 dataset "e_V": shape (33812183,), type "<f8">
# e_W
# <HDF5 dataset "e_W": shape (33812183,), type "<f8">
# e_XGC
# <HDF5 dataset "e_XGC": shape (33812183,), type "<f8">
# e_YGC
# <HDF5 dataset "e_YGC": shape (33812183,), type "<f8">
# e_ZGC
# <HDF5 dataset "e_ZGC": shape (33812183,), type "<f8">
# e_apo
# <HDF5 dataset "e_apo": shape (33812183,), type "<f8">
# e_ecc
# <HDF5 dataset "e_ecc": shape (33812183,), type "<f8">
# e_peri
# <HDF5 dataset "e_peri": shape (33812183,), type "<f8">
# e_vphi
# <HDF5 dataset "e_vphi": shape (33812183,), type "<f8">
# e_vr
# <HDF5 dataset "e_vr": shape (33812183,), type "<f8">
# e_vz
# <HDF5 dataset "e_vz": shape (33812183,), type "<f8">
# e_zmax
# <HDF5 dataset "e_zmax": shape (33812183,), type "<f8">
# ecc
# <HDF5 dataset "ecc": shape (33812183,), type "<f8">
# f_v_forder
# <HDF5 dataset "f_v_forder": shape (33812183,), type "<f8">
# parallax_zpcorr
# <HDF5 dataset "parallax_zpcorr": shape (33812183,), type "<f8">
# peri
# <HDF5 dataset "peri": shape (33812183,), type "<f8">
# source_id
# <HDF5 dataset "source_id": shape (33812183,), type "<i8">
# vphi
# <HDF5 dataset "vphi": shape (33812183,), type "<f8">
# vr
# <HDF5 dataset "vr": shape (33812183,), type "<f8">
# vz
# <HDF5 dataset "vz": shape (33812183,), type "<f8">
# zero_point_correction
# <HDF5 dataset "zero_point_correction": shape (33812183,), type "<f4">
# zmax
# <HDF5 dataset "zmax": shape (33812183,), type "<f8">

# %%
df = pd.read_pickle('DR3_6D_kinematics.pkl')

# %%
df.to_csv('DR3_6D_kinematics.csv')
