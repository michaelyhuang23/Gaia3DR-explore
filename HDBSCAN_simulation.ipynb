# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('./data/m12i_cluster_data.h5', key='star')

# %%
df.head()
# Out:
#         Unnamed: 0       feH  id_stars  radial_distance_stars  redshift_stars  \
# 73008        73008 -3.873608   4327099               9.211095        2.586207
# 73089        73089 -2.688378  12736793              15.952224        2.586207
# 155921      155921 -2.053396   4764646              14.881052        1.100000
# 155922      155922 -2.973717   9335794              12.130770        1.100000
# 155924      155924 -3.693150  10771403              15.310860        1.100000
#
#         snap_list_stars    star_mass  subhalo_mass_stars  subhalo_peak_mass  \
# 73008               138  4980.819555           7212108.0         22792022.0
# 73089               138  4835.979771           7212108.0         22792022.0
# 155921              262  5222.007720          15022792.0         23190884.0
# 155922              262  5066.419914          15022792.0         23190884.0
# 155924              262  4728.352183          15022792.0         23190884.0
#
# ...
